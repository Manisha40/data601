# %% [markdown]
# # Week 11 Homework
#
# Write a class that generates fake data.
#
# * Write the code under the py docs ( do NOT remove docs strings)
# * Before comitting do a Restart & Run All
#
# Make sure that if a dataframe is passed in, it should not remove any value from it.

# %%
pip install Faker
# Out:
# Collecting Faker
#   Downloading Faker-9.8.2-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 27.2 MB/s
# Requirement already satisfied: typing-extensions>=3.10.0.2 in /usr/local/lib/python3.7/dist-packages (from Faker) (3.10.0.2)
# Requirement already satisfied: text-unidecode==1.3 in /usr/local/lib/python3.7/dist-packages (from Faker) (1.3)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.7/dist-packages (from Faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.4->Faker) (1.15.0)
# Installing collected packages: Faker
# Successfully installed Faker-9.8.2

# %%
from faker import Faker
import pandas as pd
import numpy as np
import faker 
class FakeDataGenerator:
    
    def __init__(self, df = None, rows=5):
        """
        This class generates fake data
        
        If data frame is passed in it will add the fake data to it. 
        Otherwise, it will create a new data frame
        
        Parameters:
        -----------
        df: 
          DataFrame default is None
          
        rows:
          If df None, this parameter will be used to create a data frame with `row` lenght
        """
        # code goes under this line. 
        # I will deduct points if any code is written above the comments!    

        self.profile = Faker()
        
        if df is not None:
            self.df = df
            self.rows = len(df)
        else:
            self.df = pd.DataFrame()
            self.rows = rows
        
        
    def add_random_number(self, column_name, small_value, high_value): # optional: add probabilities 
        """
        adds fake numbers to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        self.small_value=small_value
        self.high_value=high_value
        for i in range(1,25):
                  self.df[column_name]=[self.profile.random_int(self.small_value,self.high_value) for i in range(25)]
        return self.df       
    
        
    def add_first_name(self, column_name):
        """
        adds fake first name to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        for i in range(1,25):
                  self.df[column_name]=[self.profile.first_name() for i in range(25)]
        return self.df
    
    
    def add_last_name(self, column_name):
        """
        adds fake last name to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        for i in range(1,25):
                  self.df[column_name]=[self.profile.last_name() for i in range(25)]
        return self.df
              
    
    def add_email(self, column_name):
        """
        adds fake email to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        for i in range(1,25):
                  self.df[column_name]=[self.profile.email() for i in range(25)]          
        return self.df
    
    
    def add_phone_number(self, column_name):
        """
        adds fake name to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        for i in range(1,25):
                  self.df[column_name]=[self.profile.phone_number() for i in range(25)]
        return self.df
    
    
    def add_address(self, column_name):
        """
        adds fake name to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        for i in range(1,25):
                  self.df[column_name]=[self.profile.address() for i in range(25)]
        return self.df

# %%
import pandas as pd

# Case 1 - existing data frame 
df = pd.DataFrame()
df['product_id'] = [i + 123 for i in range(25)]
df.head()
# Out:
#    product_id
# 0         123
# 1         124
# 2         125
# 3         126
# 4         127

# %%
fakeGen = FakeDataGenerator(df) # I'm creating instance using existing df
fakeGen.add_first_name('firstname')
fakeGen.add_last_name('lastname')
fakeGen.add_address('shipping_address')
fakeGen.add_address('billing_address')
fakeGen.add_phone_number('customer_phone')
# Out:
#     product_id  ...          customer_phone
# 0          123  ...              5532467815
# 1          124  ...      (995)153-4379x6372
# 2          125  ...        139.524.3958x714
# 3          126  ...       (483)782-2163x058
# 4          127  ...       (626)515-5429x517
# 5          128  ...            236-278-3110
# 6          129  ...        001-576-519-7226
# 7          130  ...           (694)968-1150
# 8          131  ...       (365)421-2511x594
# 9          132  ...    +1-192-720-2602x0212
# 10         133  ...            886-406-0887
# 11         134  ...            551.673.7913
# 12         135  ...           (690)315-1848
# 13         136  ...   001-348-737-2198x6455
# 14         137  ...       098-363-6963x6341
# 15         138  ...   +1-991-733-3740x57996
# 16         139  ...       784-268-7141x2777
# 17         140  ...            532-945-4651
# 18         141  ...      896-488-0328x59460
# 19         142  ...              7803611251
# 20         143  ...           (123)846-1556
# 21         144  ...       211-881-2346x0960
# 22         145  ...  001-552-185-5875x13616
# 23         146  ...  001-955-531-4191x91837
# 24         147  ...           (680)250-2083
#
# [25 rows x 6 columns]

# %%
# Case 2 - no dataframe

fakeGen = FakeDataGenerator() # no df
fakeGen.add_address('shipping_address')
fakeGen.add_address('billing_address')
fakeGen.add_phone_number('customer_phone')
fakeGen.add_random_number('sale_count', 10, 100)
# Out:
#                                      shipping_address  ... sale_count
# 0   2491 Thomas Corner Apt. 809\nPort William, PA ...  ...         48
# 1    0543 Herring Trafficway\nSouth Amyland, IL 79524  ...         47
# 2   3661 Walton Path Suite 382\nMurphychester, OH ...  ...         89
# 3          325 Sanchez View\nJohnsonborough, MI 16325  ...         79
# 4              5046 Thomas Fort\nMichaelton, OH 80130  ...         64
# 5    91212 Davis Burgs Apt. 936\nLake Emily, CT 14952  ...         55
# 6                         USCGC Simmons\nFPO AA 34137  ...         70
# 7           937 Farmer Summit\nCharlesville, WY 39007  ...         51
# 8       81130 Nicholas Groves\nRodriguezton, WV 75769  ...         94
# 9     9961 King Mills Apt. 105\nLangborough, NY 33593  ...         78
# 10              45088 Chad Courts\nHillfurt, NH 77833  ...         95
# 11  568 Antonio Ford Suite 440\nWest Catherinetown...  ...         58
# 12       703 Brady Brooks\nNew Michaelmouth, IA 60454  ...         20
# 13                168 Johnson Way\nSeanfurt, AL 31651  ...         80
# 14                   PSC 3265, Box 0874\nAPO AA 54851  ...         48
# 15     915 Bradley Club Apt. 875\nBakerview, SC 72315  ...         92
# 16           5081 Tim Harbors\nCollinsshire, UT 21983  ...         20
# 17                   Unit 4736 Box 4636\nDPO AE 26928  ...         36
# 18     6141 Hicks Branch\nSouth Raymondtown, ND 53635  ...         30
# 19        8103 Sylvia Streets\nJonathanbury, NY 41439  ...         10
# 20                   PSC 8947, Box 2164\nAPO AE 18848  ...         77
# 21     44423 Michael Track\nLake Meganshire, UT 60187  ...         38
# 22   942 Burke Path Suite 874\nThompsonfurt, WY 20640  ...         15
# 23               586 Diaz Green\nFosterberg, LA 99255  ...         57
# 24                   Unit 2355 Box 6906\nDPO AA 43538  ...         14
#
# [25 rows x 4 columns]
