# %% [markdown]
# # Week6 Lab
#
# ## Download & Extract Data
#
# Programmatically download the zip file & extract

# %%
from zipfile import ZipFile

# %%
from urllib import request

def download_file(file_name, url):
    res = request.urlopen(url)
    with open(file_name,'wb') as file:
        file.write(res.read())

# %%
file_url = 'https://github.com/msaricaumbc/DS601_Fall21/raw/main/Week06/data/lab_data.zip'
file_name = 'lab_data.zip'

download_file(file_name, file_url)

# %%
def unzip(file_name, path='./'):
    # opening the zip file in READ mode 
    with ZipFile(file_name, 'r') as zip: 
        # printing all the contents of the zip file 
        zip.printdir() 

        # extracting all the files 
        print('Extracting all the files now...') 
        zip.extractall(path = path) 
        print('Done!')

# %%
unzip(file_name)
# Out:
# File Name                                             Modified             Size
# PoliceShootingsUS.csv                          2021-09-21 20:53:54       227653
# __MACOSX/._PoliceShootingsUS.csv               2021-09-21 20:53:54          276
# volunteers.txt                                 2021-10-06 00:32:28         7015
# __MACOSX/._volunteers.txt                      2021-10-06 00:32:28          176
# Extracting all the files now...
# Done!

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is B253-5DEB
#
#  Directory of C:\Users\Manisha
#
# 06-10-2021  20:45    <DIR>          .
# 06-10-2021  20:45    <DIR>          ..
# 03-08-2018  10:22    <DIR>          .anaconda
# 29-03-2020  06:26    <DIR>          .android
# 08-12-2018  07:15    <DIR>          .AndroidStudio3.2
# 15-09-2021  21:40               104 .bash_history
# 08-06-2021  05:57    <DIR>          .conda
# 15-07-2020  02:59                43 .condarc
# 15-09-2021  20:10                63 .gitconfig
# 08-12-2018  08:11    <DIR>          .gradle
# 01-11-2018  06:27    <DIR>          .idlerc
# 06-10-2021  20:31    <DIR>          .ipynb_checkpoints
# 03-08-2018  10:27    <DIR>          .ipython
# 03-10-2021  23:04    <DIR>          .jupyter
# 09-08-2018  05:46    <DIR>          .matplotlib
# 04-02-2020  08:39    <DIR>          .nbi
# 26-06-2018  23:56    <DIR>          .netbeans-derby
# 17-07-2018  02:33    <DIR>          .oracle_jre_usage
# ...

# %% [markdown]
# ## Reading data from a csv file

# %% [markdown]
# For the file `PoliceShootingsUS.csv`, please answer the following questions:
#
# * How many offenders are older than 55?

# %%
## Your code is here
import pandas as pd
df = pd.read_csv("PoliceShootingsUS.csv",encoding='windows-1252')
df
# Out:
#         id                              name      date   manner_of_death  \
# 0        3                        Tim Elliot  02/01/15              shot
# 1        4                  Lewis Lee Lembke  02/01/15              shot
# 2        5                John Paul Quintero  03/01/15  shot and Tasered
# 3        8                   Matthew Hoffman  04/01/15              shot
# 4        9                 Michael Rodriguez  04/01/15              shot
# 5       11                 Kenneth Joe Brown  04/01/15              shot
# 6       13               Kenneth Arnold Buck  05/01/15              shot
# 7       15                     Brock Nichols  06/01/15              shot
# 8       16                     Autumn Steele  06/01/15              shot
# 9       17                   Leslie Sapp III  06/01/15              shot
# 10      19                    Patrick Wetter  06/01/15  shot and Tasered
# 11      21                         Ron Sneed  07/01/15              shot
# ...

# %%
new_df= df.loc[df['age']>55]
new_df
# Out:
#         id                        name      date   manner_of_death  \
# 19      38               Jimmy Foreman  09/01/15              shot
# 29      52            Talbot Schroeder  14/01/15              shot
# 30      54              Robert Edwards  14/01/15              shot
# 43      83               Carter Castle  18/01/15  shot and Tasered
# 52     336        Robert Francis Mesch  23/01/15              shot
# 54     102  Jose Antonio Espinoza Ruiz  23/01/15              shot
# 59     110            William Campbell  25/01/15              shot
# 61     324               Raymond Kmetz  26/01/15              shot
# 77     114               David Kassick  02/02/15              shot
# 89     128  Paul Alfred Eugene Johnson  05/02/15              shot
# 92     554                 James Allen  07/02/15              shot
# 95     133             Vincent Cordaro  08/02/15              shot
# 98     136            Kenneth Kreyssig  09/02/15              shot
# ...

# %%
new_df.shape[0]
# Out:
# 235

# %% [markdown]
# * What's the age distribution?

# %%
## Your code is here
df.age.hist()

# %% [markdown]
# ## Dirty data
#
# Read `volunteers.txt` file and perform the following action:
#
# * Create a dataframe with columns: Name, Lastname, State

# %%
## Your code is here
a= pd.read_csv("volunteers.txt", header=None)
a.head()
# Out:
#              0                                                  1
# 0  log[Harding   Christine] (Virginia) - Universal human-resou...
# 1    log[Davis   Kimberly] (New York) - Compatible demand-driv...
# 2   log[Ingram   Rachel] (Louisiana) - Versatile multimedia we...
# 3   log[Walker   Richard] (Oregon) - Networked eco-centric app...
# 4   log[Barnes   Francisco] (Virginia) - Persistent systematic...

# %%
a[0].head()
# Out:
# 0    log[Harding
# 1      log[Davis
# 2     log[Ingram
# 3     log[Walker
# 4     log[Barnes
# Name: 0, dtype: object

# %%
a[1].head()
# Out:
# 0     Christine] (Virginia) - Universal human-resou...
# 1     Kimberly] (New York) - Compatible demand-driv...
# 2     Rachel] (Louisiana) - Versatile multimedia we...
# 3     Richard] (Oregon) - Networked eco-centric app...
# 4     Francisco] (Virginia) - Persistent systematic...
# Name: 1, dtype: object

# %%
lname = [line.replace("log","")for line in a[0]]
lastname=[line.replace("[","")for line in lname]
lastname
# Out:
# ['Harding',
#  'Davis',
#  'Ingram',
#  'Walker',
#  'Barnes',
#  'Perez',
#  'Choi',
#  'Gomez',
#  'Lloyd',
#  'Moore',
#  'Murray',
#  'Moore',
#  'Jones',
#  'Morales',
#  'Hogan',
#  'Floyd',
#  'Scott',
#  'Johnson',
#  'Taylor',
#  'Freeman',
#  'Humphrey',
#  'Schultz',
#  'Harper',
#  'Shaw',
#  'Glenn',
#  'Jackson',
#  'Rivera',
#  'Robinson',
#  'Taylor',
#  'Harper',
#  'Smith',
#  'Chavez',
#  'Thompson',
#  'Gibson',
#  'Taylor',
#  'Mitchell',
#  'Simmons',
#  'Ramirez',
#  'Lopez',
#  'Rose',
#  'Brown',
#  'Zimmerman',
#  'Martinez',
#  'Mack',
#  'Harris',
#  'Foster',
#  'Hines',
#  'Fields',
#  'Austin',
#  'Choi',
#  'Jacobs',
#  'Morales',
#  'Morales',
#  'Payne',
#  'Harmon',
#  'Hooper',
#  'Henry',
#  'Bell',
#  'Mercado',
#  'Nelson',
#  'Lewis',
#  'Tanner',
#  'Zavala',
#  'Taylor',
#  'Diaz',
#  'Peterson',
#  'Johnson',
#  'Daniel',
#  'Bartlett',
#  'Orozco',
#  'Bailey',
#  'Hardin',
#  'Hartman',
#  'Camacho',
#  'Hardy',
#  'Ward',
#  'Jenkins',
# ...

# %%
fname = [line.replace("]","")for line in a[1]]
fname
# Out:
# [' Christine (Virginia) - Universal human-resource flexibility',
#  ' Kimberly (New York) - Compatible demand-driven hub',
#  ' Rachel (Louisiana) - Versatile multimedia website',
#  ' Richard (Oregon) - Networked eco-centric approach',
#  ' Francisco (Virginia) - Persistent systematic moratorium',
#  ' Rachel (Alaska) - Optimized national portal',
#  ' Linda (Iowa) - Operative discrete Internet solution',
#  ' Janice (Vermont) - Managed national attitude',
#  ' Jesus (Connecticut) - Adaptive systematic definition',
#  ' Alicia (Michigan) - Innovative motivating support',
#  ' Pamela (Arizona) - Diverse systematic policy',
#  ' Brittney (Washington) - Progressive web-enabled synergy',
#  ' Alexander (Arizona) - Advanced 24/7 data-warehouse',
#  ' David (Florida) - Streamlined eco-centric conglomeration',
#  ' Elizabeth (Rhode Island) - Re-engineered demand-driven groupware',
#  ' Courtney (Pennsylvania) - Cloned real-time collaboration',
# ...

# %%
people= {}
people['Name']=[] #names=[]
people['Lastname']=[] #lastnames=[]
people['State']=[] #states=[]



with open("volunteers.txt", 'r') as file:
    lines = file.readlines()
    for line in lines:
        
        line = line \
                    .replace('"',',')\
                    .replace('[',',')\
                    .replace(']',',')\
                    .replace('(',',')\
                    .replace(')',',')\
                    .replace('-',',')
        #print(line) 
        parts = line.split(',')
        #print(parts)
        lastname = parts[3].strip()
        name = parts[4].strip()
        state = parts[6].strip()
        
        people['Name'].append(name)   #names.append(name)
        people['Lastname'].append(lastname) #lastnames.append(lastname)
        people['State'].append(state)#states.append(state)

df1 = pd.DataFrame(people)
df1


#df = pd.Dataframe()\
#df['Name']=names
#df['Lastname']=lastnames
#df['Sate']=states
#df
# Out:
#       Lastname       Name           State
# 0      Harding  Christine        Virginia
# 1        Davis   Kimberly        New York
# 2       Ingram     Rachel       Louisiana
# 3       Walker    Richard          Oregon
# 4       Barnes  Francisco        Virginia
# 5        Perez     Rachel          Alaska
# 6         Choi      Linda            Iowa
# 7        Gomez     Janice         Vermont
# 8        Lloyd      Jesus     Connecticut
# 9        Moore     Alicia        Michigan
# 10      Murray     Pamela         Arizona
# 11       Moore   Brittney      Washington
# 12       Jones  Alexander         Arizona
# 13     Morales      David         Florida
# 14       Hogan  Elizabeth    Rhode Island
# 15       Floyd   Courtney    Pennsylvania
# 16       Scott       Mark   West Virginia
# 17     Johnson     Philip  North Carolina
# 18      Taylor    Michael   New Hampshire
# 19     Freeman    Barbara    Pennsylvania
# 20    Humphrey      Shawn        Oklahoma
# ...
